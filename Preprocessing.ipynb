# %% [markdown]
# ### Let's try to extract the nodes first

# %%
import cv2
import numpy as np
import pandas as pd
from glob import glob
import os
import easyocr
import pytesseract
import torch
import torch.nn as nn
import torch.optim as optim
from collections import Counter
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import StratifiedKFold

# %%
def detect_nodes(image):
    """
    Detect circular nodes in the graph
    Returns node positions and radii
    """
    # Convert to grayscale if necessary
    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image

    # Apply Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Use Hough Circle Transform to detect circles
    circles = cv2.HoughCircles(
        blurred,
        cv2.HOUGH_GRADIENT,
        dp=1,
        minDist=10,
        param1=50,
        param2=30,
        minRadius=15,
        maxRadius=40
    )

    # If no circles are detected, try alternative approach with blob detection
    if circles is None:
        # Set up SimpleBlobDetector parameters
        params = cv2.SimpleBlobDetector_Params()
        params.filterByCircularity = True
        params.minCircularity = 0.8
        params.filterByConvexity = True
        params.minConvexity = 0.9
        params.filterByInertia = True
        params.minInertiaRatio = 0.5

        detector = cv2.SimpleBlobDetector_create(params)
        keypoints = detector.detect(blurred)

        # Convert keypoints to circles format
        circles = np.array([[[kp.pt[0], kp.pt[1], kp.size / 2]] for kp in keypoints])

    return circles[0] if circles is not None else np.array([])

# %%
def draw_detected_circles(image, circles):
    """
    Draws detected circles on the image.

    Parameters:
        image (np.array): Original image.
        circles (np.array): Nx3 array of circles [x, y, radius].

    Returns:
        image_with_circles (np.array): Image with circles drawn.
    """
    # Make a copy to draw on
    output = image.copy()

    # Ensure circles is in expected shape
    if circles is not None and len(circles) > 0:
        for circle in circles:
            x, y, r = int(circle[0]), int(circle[1]), int(circle[2])
            # Draw the circle outline
            cv2.circle(output, (x, y), r, (0, 255, 0), 2)
            # Draw the center of the circle
            cv2.circle(output, (x, y), 2, (0, 0, 255), 3)
    else:
        print("No circles to draw.")
    return output

# %%
# Detect circles
image = cv2.imread("graphs_images/1.png")
circles = detect_nodes(image)
mean_radius = np.mean(circles[:,2])
scale = 24.1/mean_radius
width = int(image.shape[1] * scale)
height = int(image.shape[0] * scale)
scaled_image = cv2.resize(image, (width, height))
circles = detect_nodes(scaled_image)

image_with_circles = draw_detected_circles(scaled_image, circles)
# Show image (for debugging)
cv2.imshow("Detected Circles", image_with_circles)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
np.mean(circles[:,2])
# Out:
# np.float32(24.249998)

# %% [markdown]
# ### I shall build a number classifier for the nodes.  For this I will have to build a dataset and train a model on it

# %% [markdown]
# #### The following code crops the images of nodes and saves them as separate images

# %%
input_dir = "./graphs_images"
output_dir = "./images"
csv_path = "node.csv"

os.makedirs(output_dir, exist_ok=True)
image_files = glob(os.path.join(input_dir, "*.png"))
records = []
node_counter = 0

for image_path in image_files:
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to read {image_path}")
        continue

    initial_circles = detect_nodes(image)
    if len(initial_circles) == 0:
        print(f"No nodes detected in {image_path}")
        continue

    mean_radius = np.mean(initial_circles[:, 2])
    scale = 24.1 / mean_radius
    width = int(image.shape[1] * scale)
    height = int(image.shape[0] * scale)
    scaled_image = cv2.resize(image, (width, height))
    circles = detect_nodes(scaled_image)

    for circle in circles:
        x, y, r = int(circle[0]), int(circle[1]), int(circle[2])
        x1 = max(0, x - r)
        y1 = max(0, y - r)
        x2 = min(scaled_image.shape[1], x + r)
        y2 = min(scaled_image.shape[0], y + r)

        cropped = scaled_image[y1:y2, x1:x2]
        filename = f"node_{node_counter:05d}.png"
        cv2.imwrite(os.path.join(output_dir, filename), cropped)
        records.append({"filename": filename, "key": ""})
        node_counter += 1

    print(f"Processed {os.path.basename(image_path)} -> {len(circles)} nodes")

df = pd.DataFrame(records)
df.to_csv(csv_path, index=False)

print(f"\nDone! Saved {node_counter} node images and '{csv_path}'")
# Out:
# Processed 329.png -> 3 nodes
# Processed 4.png -> 6 nodes
# Processed 84.png -> 5 nodes
# Processed 390.png -> 3 nodes
# Processed 269.png -> 5 nodes
# Processed 292.png -> 3 nodes
# Processed 246.png -> 6 nodes
# Processed 25.png -> 5 nodes
# Processed 377.png -> 5 nodes
# Processed 132.png -> 6 nodes
# Processed 196.png -> 6 nodes
# Processed 330.png -> 5 nodes
# Processed 391.png -> 6 nodes
# Processed 171.png -> 6 nodes
# Processed 75.png -> 5 nodes
# Processed 68.png -> 6 nodes
# Processed 412.png -> 6 nodes
# Processed 371.png -> 5 nodes
# Processed 76.png -> 4 nodes
# Processed 300.png -> 5 nodes
# Processed 274.png -> 4 nodes
# Processed 159.png -> 6 nodes
# Processed 147.png -> 6 nodes
# Processed 213.png -> 4 nodes
# Processed 344.png -> 3 nodes
# Processed 266.png -> 4 nodes
# Processed 452.png -> 6 nodes
# Processed 157.png -> 3 nodes
# Processed 409.png -> 6 nodes
# Processed 1.png -> 4 nodes
# Processed 99.png -> 3 nodes
# Processed 383.png -> 3 nodes
# Processed 345.png -> 3 nodes
# Processed 197.png -> 4 nodes
# Processed 15.png -> 5 nodes
# Processed 67.png -> 6 nodes
# Processed 59.png -> 5 nodes
# Processed 424.png -> 4 nodes
# Processed 368.png -> 4 nodes
# Processed 39.png -> 5 nodes
# Processed 351.png -> 5 nodes
# Processed 376.png -> 5 nodes
# Processed 440.png -> 6 nodes
# Processed 200.png -> 4 nodes
# Processed 55.png -> 3 nodes
# Processed 449.png -> 5 nodes
# Processed 160.png -> 5 nodes
# Processed 129.png -> 5 nodes
# Processed 459.png -> 6 nodes
# Processed 488.png -> 5 nodes
# Processed 279.png -> 5 nodes
# Processed 369.png -> 5 nodes
# Processed 26.png -> 5 nodes
# Processed 121.png -> 5 nodes
# Processed 27.png -> 6 nodes
# Processed 212.png -> 3 nodes
# Processed 475.png -> 3 nodes
# Processed 398.png -> 3 nodes
# Processed 379.png -> 4 nodes
# Processed 438.png -> 6 nodes
# Processed 346.png -> 4 nodes
# Processed 338.png -> 4 nodes
# Processed 71.png -> 4 nodes
# Processed 433.png -> 6 nodes
# Processed 47.png -> 6 nodes
# Processed 280.png -> 6 nodes
# Processed 482.png -> 4 nodes
# Processed 191.png -> 6 nodes
# Processed 471.png -> 5 nodes
# Processed 455.png -> 6 nodes
# Processed 256.png -> 4 nodes
# Processed 478.png -> 6 nodes
# Processed 105.png -> 6 nodes
# Processed 41.png -> 6 nodes
# Processed 125.png -> 4 nodes
# Processed 11.png -> 6 nodes
# Processed 128.png -> 4 nodes
# Processed 408.png -> 3 nodes
# Processed 495.png -> 3 nodes
# Processed 123.png -> 5 nodes
# Processed 357.png -> 4 nodes
# Processed 106.png -> 3 nodes
# Processed 259.png -> 3 nodes
# Processed 238.png -> 4 nodes
# Processed 51.png -> 5 nodes
# Processed 137.png -> 4 nodes
# Processed 380.png -> 4 nodes
# Processed 288.png -> 5 nodes
# Processed 282.png -> 3 nodes
# Processed 484.png -> 3 nodes
# Processed 165.png -> 5 nodes
# Processed 64.png -> 3 nodes
# Processed 127.png -> 6 nodes
# Processed 356.png -> 5 nodes
# Processed 170.png -> 4 nodes
# Processed 134.png -> 5 nodes
# Processed 384.png -> 4 nodes
# Processed 295.png -> 5 nodes
# Processed 352.png -> 4 nodes
# Processed 253.png -> 5 nodes
# Processed 333.png -> 4 nodes
# Processed 491.png -> 4 nodes
# Processed 116.png -> 5 nodes
# Processed 190.png -> 3 nodes
# Processed 139.png -> 6 nodes
# Processed 466.png -> 6 nodes
# Processed 453.png -> 3 nodes
# Processed 168.png -> 5 nodes
# Processed 420.png -> 3 nodes
# Processed 370.png -> 4 nodes
# Processed 201.png -> 4 nodes
# Processed 427.png -> 3 nodes
# Processed 144.png -> 4 nodes
# Processed 154.png -> 5 nodes
# Processed 21.png -> 6 nodes
# Processed 342.png -> 5 nodes
# Processed 272.png -> 5 nodes
# Processed 151.png -> 3 nodes
# Processed 397.png -> 3 nodes
# Processed 473.png -> 5 nodes
# Processed 32.png -> 6 nodes
# Processed 263.png -> 3 nodes
# Processed 278.png -> 6 nodes
# Processed 79.png -> 3 nodes
# Processed 37.png -> 4 nodes
# Processed 131.png -> 3 nodes
# Processed 16.png -> 4 nodes
# Processed 435.png -> 5 nodes
# Processed 286.png -> 5 nodes
# Processed 49.png -> 4 nodes
# Processed 284.png -> 3 nodes
# Processed 77.png -> 6 nodes
# Processed 126.png -> 4 nodes
# Processed 432.png -> 4 nodes
# Processed 252.png -> 6 nodes
# Processed 267.png -> 5 nodes
# Processed 394.png -> 5 nodes
# Processed 439.png -> 6 nodes
# Processed 204.png -> 6 nodes
# Processed 285.png -> 5 nodes
# Processed 101.png -> 3 nodes
# Processed 185.png -> 4 nodes
# Processed 362.png -> 6 nodes
# Processed 109.png -> 5 nodes
# Processed 385.png -> 3 nodes
# Processed 386.png -> 4 nodes
# Processed 343.png -> 3 nodes
# Processed 112.png -> 5 nodes
# Processed 419.png -> 6 nodes
# Processed 360.png -> 3 nodes
# Processed 382.png -> 4 nodes
# Processed 359.png -> 5 nodes
# Processed 265.png -> 4 nodes
# Processed 180.png -> 4 nodes
# Processed 492.png -> 5 nodes
# Processed 451.png -> 4 nodes
# Processed 387.png -> 3 nodes
# Processed 28.png -> 5 nodes
# Processed 401.png -> 3 nodes
# Processed 251.png -> 6 nodes
# Processed 472.png -> 6 nodes
# Processed 207.png -> 5 nodes
# Processed 34.png -> 5 nodes
# Processed 249.png -> 3 nodes
# Processed 469.png -> 5 nodes
# Processed 162.png -> 4 nodes
# Processed 45.png -> 5 nodes
# Processed 178.png -> 5 nodes
# Processed 62.png -> 3 nodes
# Processed 477.png -> 6 nodes
# Processed 434.png -> 6 nodes
# Processed 93.png -> 4 nodes
# Processed 358.png -> 6 nodes
# Processed 348.png -> 4 nodes
# Processed 206.png -> 4 nodes
# Processed 17.png -> 6 nodes
# Processed 199.png -> 5 nodes
# Processed 317.png -> 5 nodes
# Processed 366.png -> 4 nodes
# Processed 350.png -> 3 nodes
# Processed 202.png -> 6 nodes
# Processed 448.png -> 5 nodes
# Processed 480.png -> 4 nodes
# Processed 268.png -> 4 nodes
# Processed 479.png -> 6 nodes
# Processed 308.png -> 4 nodes
# Processed 363.png -> 3 nodes
# Processed 141.png -> 4 nodes
# Processed 223.png -> 6 nodes
# Processed 78.png -> 4 nodes
# Processed 468.png -> 6 nodes
# Processed 2.png -> 3 nodes
# Processed 441.png -> 4 nodes
# Processed 231.png -> 4 nodes
# Processed 322.png -> 4 nodes
# Processed 195.png -> 5 nodes
# Processed 431.png -> 3 nodes
# Processed 179.png -> 5 nodes
# Processed 8.png -> 6 nodes
# Processed 442.png -> 3 nodes
# Processed 236.png -> 5 nodes
# Processed 355.png -> 3 nodes
# Processed 415.png -> 6 nodes
# Processed 454.png -> 5 nodes
# Processed 430.png -> 6 nodes
# Processed 214.png -> 6 nodes
# Processed 40.png -> 5 nodes
# Processed 464.png -> 3 nodes
# Processed 174.png -> 5 nodes
# Processed 103.png -> 3 nodes
# Processed 315.png -> 3 nodes
# Processed 22.png -> 3 nodes
# Processed 276.png -> 3 nodes
# Processed 393.png -> 6 nodes
# Processed 53.png -> 6 nodes
# Processed 80.png -> 6 nodes
# Processed 3.png -> 4 nodes
# Processed 353.png -> 4 nodes
# Processed 145.png -> 4 nodes
# Processed 461.png -> 6 nodes
# Processed 194.png -> 3 nodes
# Processed 54.png -> 5 nodes
# Processed 81.png -> 3 nodes
# Processed 418.png -> 5 nodes
# Processed 172.png -> 3 nodes
# Processed 294.png -> 5 nodes
# Processed 43.png -> 3 nodes
# Processed 428.png -> 5 nodes
# Processed 250.png -> 5 nodes
# Processed 323.png -> 6 nodes
# Processed 327.png -> 3 nodes
# Processed 297.png -> 5 nodes
# Processed 205.png -> 5 nodes
# Processed 283.png -> 3 nodes
# Processed 164.png -> 5 nodes
# Processed 273.png -> 6 nodes
# Processed 203.png -> 6 nodes
# Processed 18.png -> 5 nodes
# Processed 445.png -> 4 nodes
# Processed 302.png -> 5 nodes
# Processed 224.png -> 5 nodes
# Processed 309.png -> 4 nodes
# Processed 243.png -> 4 nodes
# Processed 186.png -> 6 nodes
# Processed 422.png -> 5 nodes
# Processed 217.png -> 5 nodes
# Processed 260.png -> 3 nodes
# Processed 405.png -> 4 nodes
# Processed 211.png -> 4 nodes
# Processed 304.png -> 5 nodes
# Processed 364.png -> 4 nodes
# Processed 413.png -> 6 nodes
# Processed 119.png -> 5 nodes
# Processed 331.png -> 6 nodes
# Processed 82.png -> 4 nodes
# Processed 124.png -> 5 nodes
# Processed 421.png -> 5 nodes
# Processed 221.png -> 6 nodes
# Processed 403.png -> 5 nodes
# Processed 176.png -> 4 nodes
# Processed 320.png -> 6 nodes
# Processed 489.png -> 4 nodes
# Processed 9.png -> 4 nodes
# Processed 42.png -> 4 nodes
# Processed 483.png -> 6 nodes
# Processed 96.png -> 5 nodes
# Processed 392.png -> 6 nodes
# Processed 324.png -> 5 nodes
# Processed 374.png -> 6 nodes
# Processed 299.png -> 6 nodes
# Processed 237.png -> 5 nodes
# Processed 500.png -> 4 nodes
# Processed 44.png -> 6 nodes
# Processed 242.png -> 6 nodes
# Processed 220.png -> 6 nodes
# Processed 215.png -> 6 nodes
# Processed 257.png -> 3 nodes
# Processed 13.png -> 6 nodes
# Processed 60.png -> 4 nodes
# Processed 486.png -> 4 nodes
# Processed 182.png -> 6 nodes
# Processed 493.png -> 4 nodes
# Processed 361.png -> 3 nodes
# Processed 349.png -> 5 nodes
# Processed 407.png -> 6 nodes
# Processed 188.png -> 6 nodes
# Processed 312.png -> 5 nodes
# Processed 303.png -> 5 nodes
# Processed 161.png -> 6 nodes
# Processed 354.png -> 4 nodes
# Processed 319.png -> 4 nodes
# Processed 254.png -> 3 nodes
# Processed 335.png -> 6 nodes
# Processed 465.png -> 5 nodes
# Processed 87.png -> 3 nodes
# Processed 443.png -> 5 nodes
# Processed 216.png -> 4 nodes
# Processed 65.png -> 4 nodes
# Processed 429.png -> 3 nodes
# Processed 423.png -> 6 nodes
# Processed 155.png -> 4 nodes
# Processed 339.png -> 3 nodes
# Processed 113.png -> 6 nodes
# Processed 275.png -> 5 nodes
# Processed 92.png -> 5 nodes
# Processed 7.png -> 3 nodes
# Processed 173.png -> 5 nodes
# Processed 436.png -> 6 nodes
# Processed 102.png -> 5 nodes
# Processed 163.png -> 5 nodes
# Processed 227.png -> 6 nodes
# Processed 181.png -> 4 nodes
# Processed 208.png -> 3 nodes
# Processed 270.png -> 4 nodes
# Processed 69.png -> 6 nodes
# Processed 497.png -> 6 nodes
# Processed 142.png -> 4 nodes
# Processed 100.png -> 3 nodes
# Processed 210.png -> 6 nodes
# Processed 378.png -> 3 nodes
# Processed 97.png -> 4 nodes
# Processed 499.png -> 5 nodes
# Processed 91.png -> 3 nodes
# Processed 24.png -> 6 nodes
# Processed 233.png -> 5 nodes
# Processed 29.png -> 5 nodes
# Processed 262.png -> 4 nodes
# Processed 152.png -> 5 nodes
# Processed 74.png -> 6 nodes
# Processed 19.png -> 3 nodes
# Processed 222.png -> 6 nodes
# Processed 90.png -> 5 nodes
# Processed 490.png -> 4 nodes
# Processed 14.png -> 4 nodes
# Processed 458.png -> 5 nodes
# Processed 381.png -> 4 nodes
# Processed 83.png -> 6 nodes
# Processed 234.png -> 4 nodes
# Processed 425.png -> 4 nodes
# Processed 400.png -> 4 nodes
# Processed 487.png -> 4 nodes
# Processed 494.png -> 5 nodes
# Processed 117.png -> 4 nodes
# Processed 133.png -> 4 nodes
# Processed 66.png -> 6 nodes
# Processed 336.png -> 6 nodes
# Processed 467.png -> 4 nodes
# Processed 325.png -> 5 nodes
# Processed 153.png -> 3 nodes
# Processed 88.png -> 6 nodes
# Processed 50.png -> 5 nodes
# Processed 444.png -> 5 nodes
# Processed 470.png -> 3 nodes
# Processed 271.png -> 6 nodes
# Processed 114.png -> 6 nodes
# Processed 115.png -> 5 nodes
# Processed 193.png -> 3 nodes
# Processed 367.png -> 5 nodes
# Processed 402.png -> 4 nodes
# Processed 410.png -> 4 nodes
# Processed 104.png -> 6 nodes
# Processed 328.png -> 5 nodes
# Processed 146.png -> 4 nodes
# Processed 177.png -> 6 nodes
# Processed 261.png -> 3 nodes
# Processed 239.png -> 3 nodes
# Processed 417.png -> 5 nodes
# Processed 230.png -> 6 nodes
# Processed 414.png -> 6 nodes
# Processed 463.png -> 6 nodes
# Processed 447.png -> 3 nodes
# Processed 73.png -> 3 nodes
# Processed 86.png -> 3 nodes
# Processed 85.png -> 3 nodes
# Processed 456.png -> 5 nodes
# Processed 158.png -> 4 nodes
# Processed 388.png -> 5 nodes
# Processed 149.png -> 5 nodes
# Processed 318.png -> 4 nodes
# Processed 150.png -> 5 nodes
# Processed 36.png -> 5 nodes
# Processed 244.png -> 4 nodes
# Processed 20.png -> 3 nodes
# Processed 135.png -> 6 nodes
# Processed 58.png -> 5 nodes
# Processed 255.png -> 4 nodes
# Processed 277.png -> 5 nodes
# Processed 56.png -> 4 nodes
# Processed 120.png -> 4 nodes
# Processed 496.png -> 4 nodes
# Processed 446.png -> 4 nodes
# Processed 12.png -> 3 nodes
# Processed 293.png -> 3 nodes
# Processed 140.png -> 6 nodes
# Processed 218.png -> 4 nodes
# Processed 167.png -> 5 nodes
# Processed 340.png -> 4 nodes
# Processed 143.png -> 6 nodes
# Processed 110.png -> 6 nodes
# Processed 57.png -> 4 nodes
# Processed 404.png -> 3 nodes
# Processed 313.png -> 5 nodes
# Processed 337.png -> 4 nodes
# Processed 296.png -> 6 nodes
# Processed 166.png -> 6 nodes
# Processed 334.png -> 4 nodes
# Processed 235.png -> 4 nodes
# Processed 298.png -> 3 nodes
# Processed 311.png -> 4 nodes
# Processed 481.png -> 5 nodes
# Processed 258.png -> 5 nodes
# Processed 209.png -> 5 nodes
# Processed 247.png -> 4 nodes
# Processed 406.png -> 4 nodes
# Processed 6.png -> 5 nodes
# Processed 314.png -> 5 nodes
# Processed 241.png -> 5 nodes
# Processed 396.png -> 3 nodes
# Processed 474.png -> 3 nodes
# Processed 245.png -> 4 nodes
# Processed 108.png -> 5 nodes
# Processed 148.png -> 5 nodes
# Processed 192.png -> 6 nodes
# Processed 232.png -> 4 nodes
# Processed 107.png -> 5 nodes
# Processed 229.png -> 5 nodes
# Processed 219.png -> 6 nodes
# Processed 240.png -> 4 nodes
# Processed 301.png -> 6 nodes
# Processed 138.png -> 4 nodes
# Processed 264.png -> 3 nodes
# Processed 184.png -> 4 nodes
# Processed 307.png -> 3 nodes
# Processed 290.png -> 4 nodes
# Processed 498.png -> 4 nodes
# Processed 70.png -> 5 nodes
# Processed 321.png -> 3 nodes
# Processed 130.png -> 3 nodes
# Processed 228.png -> 5 nodes
# Processed 111.png -> 5 nodes
# Processed 23.png -> 6 nodes
# Processed 450.png -> 6 nodes
# Processed 198.png -> 3 nodes
# Processed 485.png -> 3 nodes
# Processed 95.png -> 5 nodes
# Processed 48.png -> 3 nodes
# Processed 310.png -> 6 nodes
# Processed 248.png -> 5 nodes
# Processed 281.png -> 6 nodes
# Processed 63.png -> 4 nodes
# Processed 5.png -> 3 nodes
# Processed 476.png -> 3 nodes
# Processed 183.png -> 5 nodes
# Processed 326.png -> 6 nodes
# Processed 33.png -> 6 nodes
# Processed 341.png -> 6 nodes
# Processed 122.png -> 5 nodes
# Processed 373.png -> 4 nodes
# Processed 31.png -> 5 nodes
# Processed 189.png -> 5 nodes
# Processed 437.png -> 5 nodes
# Processed 365.png -> 3 nodes
# Processed 289.png -> 3 nodes
# Processed 305.png -> 3 nodes
# Processed 225.png -> 4 nodes
# Processed 226.png -> 4 nodes
# Processed 89.png -> 6 nodes
# Processed 426.png -> 5 nodes
# Processed 175.png -> 3 nodes
# Processed 38.png -> 5 nodes
# Processed 399.png -> 6 nodes
# Processed 10.png -> 6 nodes
# Processed 347.png -> 3 nodes
# Processed 118.png -> 6 nodes
# Processed 389.png -> 3 nodes
# Processed 457.png -> 5 nodes
# Processed 375.png -> 5 nodes
# Processed 61.png -> 4 nodes
# Processed 287.png -> 4 nodes
# Processed 94.png -> 5 nodes
# Processed 187.png -> 3 nodes
# Processed 136.png -> 3 nodes
# Processed 372.png -> 4 nodes
# Processed 416.png -> 4 nodes
# Processed 291.png -> 5 nodes
# Processed 46.png -> 4 nodes
# Processed 460.png -> 5 nodes
# Processed 52.png -> 4 nodes
# Processed 332.png -> 5 nodes
# Processed 30.png -> 6 nodes
# Processed 411.png -> 4 nodes
# Processed 395.png -> 4 nodes
# Processed 156.png -> 3 nodes
# Processed 169.png -> 5 nodes
# Processed 462.png -> 4 nodes
# Processed 306.png -> 4 nodes
# Processed 316.png -> 4 nodes
# Processed 98.png -> 3 nodes
# Processed 72.png -> 3 nodes
# Processed 35.png -> 5 nodes
#
# Done! Saved 2281 node images and 'node.csv'

# %% [markdown]
# ### I used easy ocr to help me with the labelling. Though some 0, 1,and 4  failed ocr. These were labelled tediously by hand.

# %%
# Check GPU availability
if not torch.cuda.is_available():
    print("CUDA not available. OCR will run on CPU.")
else:
    print("GPU detected. Running EasyOCR on GPU.")

image_dir = "./images"
csv_path = "node.csv"
output_csv = "nodes_labeled_easyocr.csv"

# Initialize EasyOCR reader
reader = easyocr.Reader(['en'], gpu=torch.cuda.is_available())

# OCR fallback using pytesseract
def pytesseract_ocr(image):
    config = r'--psm 10 -c tessedit_char_whitelist=0123456789'
    text = pytesseract.image_to_string(image, config=config)
    return text.strip()

# Preprocessing function
def preprocess_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        return None
    image = cv2.resize(image, (64, 64), interpolation=cv2.INTER_CUBIC)
    _, thresh = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return thresh

# Combined OCR function
def ocr_image(image_path):
    image = preprocess_image(image_path)
    if image is None:
        print(f"Could not load image: {image_path}")
        return ""

    # Try EasyOCR first
    result = reader.readtext(image, detail=0, paragraph=False, allowlist='0123456789')
    if result and result[0].strip().isdigit():
        return result[0].strip()

    # Fallback to pytesseract
    fallback = pytesseract_ocr(image)
    if fallback.isdigit():
        return fallback

    return ""

# Process CSV
df = pd.read_csv(csv_path)
df["key"] = ""

for idx, row in df.iterrows():
    image_path = os.path.join(image_dir, row["filename"])
    label = ocr_image(image_path)
    df.at[idx, "key"] = label
    if label:
        print(f"{row['filename']}: '{label}'")
    else:
        print(f"{row['filename']}: [OCR failed]")

df.to_csv(output_csv, index=False)
print(f"OCR labeling complete. Saved to {output_csv}")
# Out:
# GPU detected. Running EasyOCR on GPU.
# node_00000.png: [OCR failed]
# node_00001.png: [OCR failed]
# node_00002.png: '1'
# node_00003.png: [OCR failed]
# node_00004.png: '4'
# node_00005.png: '0'
# node_00006.png: '5'
# node_00007.png: [OCR failed]
# node_00008.png: '2'
# node_00009.png: '0'
# node_00010.png: '4'
# node_00011.png: '1'
# node_00012.png: '2'
# node_00013.png: '3'
# node_00014.png: [OCR failed]
# node_00015.png: [OCR failed]
# node_00016.png: '1'
# node_00017.png: [OCR failed]
# node_00018.png: '4'
# node_00019.png: '1'
# node_00020.png: '3'
# node_00021.png: '2'
# node_00022.png: [OCR failed]
# node_00023.png: [OCR failed]
# node_00024.png: '1'
# node_00025.png: '3'
# node_00026.png: '4'
# node_00027.png: '1'
# node_00028.png: '2'
# node_00029.png: '5'
# node_00030.png: [OCR failed]
# node_00031.png: '4'
# node_00032.png: '2'
# node_00033.png: '1'
# node_00034.png: '3'
# node_00035.png: '0'
# node_00036.png: [OCR failed]
# node_00037.png: '1'
# node_00038.png: '2'
# node_00039.png: '4'
# node_00040.png: '0'
# node_00041.png: '2'
# node_00042.png: '5'
# node_00043.png: '4'
# node_00044.png: '3'
# node_00045.png: '1'
# node_00046.png: '0'
# node_00047.png: '4'
# node_00048.png: '3'
# node_00049.png: '0'
# node_00050.png: '2'
# node_00051.png: '5'
# node_00052.png: '1'
# node_00053.png: '4'
# node_00054.png: '3'
# node_00055.png: [OCR failed]
# node_00056.png: '0'
# node_00057.png: '2'
# node_00058.png: '2'
# node_00059.png: '3'
# node_00060.png: '1'
# node_00061.png: '0'
# node_00062.png: '4'
# node_00063.png: '5'
# node_00064.png: '0'
# node_00065.png: '4'
# node_00066.png: '2'
# node_00067.png: '3'
# node_00068.png: '1'
# node_00069.png: '5'
# node_00070.png: '1'
# node_00071.png: '2'
# node_00072.png: '4'
# node_00073.png: [OCR failed]
# node_00074.png: [OCR failed]
# node_00075.png: '1'
# node_00076.png: '5'
# node_00077.png: '4'
# node_00078.png: '2'
# node_00079.png: [OCR failed]
# node_00080.png: '3'
# node_00081.png: '0'
# node_00082.png: '3'
# node_00083.png: '2'
# node_00084.png: '5'
# node_00085.png: '4'
# node_00086.png: '1'
# node_00087.png: '4'
# node_00088.png: '3'
# node_00089.png: '1'
# node_00090.png: '2'
# node_00091.png: '0'
# node_00092.png: '1'
# node_00093.png: [OCR failed]
# node_00094.png: '2'
# node_00095.png: '0'
# node_00096.png: '3'
# node_00097.png: '2'
# node_00098.png: '4'
# node_00099.png: [OCR failed]
# node_00100.png: '0'
# node_00101.png: [OCR failed]
# node_00102.png: '3'
# node_00103.png: '0'
# node_00104.png: '2'
# node_00105.png: '0'
# node_00106.png: '3'
# node_00107.png: '4'
# node_00108.png: '1'
# node_00109.png: '5'
# node_00110.png: '2'
# node_00111.png: '4'
# node_00112.png: '0'
# node_00113.png: '2'
# node_00114.png: '1'
# node_00115.png: '5'
# node_00116.png: [OCR failed]
# node_00117.png: '2'
# node_00118.png: '3'
# node_00119.png: [OCR failed]
# node_00120.png: '1'
# node_00121.png: [OCR failed]
# node_00122.png: [OCR failed]
# node_00123.png: '1'
# node_00124.png: '3'
# node_00125.png: '0'
# node_00126.png: [OCR failed]
# node_00127.png: '2'
# node_00128.png: '3'
# node_00129.png: '4'
# node_00130.png: '0'
# node_00131.png: '5'
# node_00132.png: [OCR failed]
# node_00133.png: '2'
# node_00134.png: [OCR failed]
# node_00135.png: [OCR failed]
# node_00136.png: '1'
# node_00137.png: '0'
# node_00138.png: '3'
# node_00139.png: '1'
# node_00140.png: '5'
# node_00141.png: '2'
# node_00142.png: '4'
# node_00143.png: '3'
# node_00144.png: '2'
# node_00145.png: [OCR failed]
# node_00146.png: '0'
# node_00147.png: [OCR failed]
# node_00148.png: [OCR failed]
# node_00149.png: '1'
# node_00150.png: [OCR failed]
# node_00151.png: [OCR failed]
# node_00152.png: '1'
# node_00153.png: [OCR failed]
# node_00154.png: [OCR failed]
# node_00155.png: '1'
# node_00156.png: '2'
# node_00157.png: '0'
# node_00158.png: '3'
# node_00159.png: [OCR failed]
# node_00160.png: [OCR failed]
# node_00161.png: [OCR failed]
# node_00162.png: [OCR failed]
# node_00163.png: '2'
# node_00164.png: '4'
# node_00165.png: '4'
# node_00166.png: '5'
# node_00167.png: '0'
# node_00168.png: [OCR failed]
# node_00169.png: '2'
# node_00170.png: '1'
# node_00171.png: '4'
# node_00172.png: '3'
# node_00173.png: '0'
# node_00174.png: '1'
# node_00175.png: '2'
# node_00176.png: [OCR failed]
# node_00177.png: '2'
# node_00178.png: '0'
# node_00179.png: '3'
# node_00180.png: [OCR failed]
# node_00181.png: '0'
# node_00182.png: [OCR failed]
# node_00183.png: '2'
# node_00184.png: [OCR failed]
# node_00185.png: '1'
# node_00186.png: '2'
# node_00187.png: '4'
# node_00188.png: '3'
# node_00189.png: [OCR failed]
# node_00190.png: '1'
# node_00191.png: '2'
# node_00192.png: '4'
# node_00193.png: '3'
# node_00194.png: '2'
# node_00195.png: [OCR failed]
# node_00196.png: '4'
# node_00197.png: '6'
# node_00198.png: '0'
# node_00199.png: '1'
# node_00200.png: '3'
# node_00201.png: '5'
# node_00202.png: '4'
# node_00203.png: '0'
# node_00204.png: '2'
# node_00205.png: '3'
# node_00206.png: [OCR failed]
# node_00207.png: '0'
# node_00208.png: '2'
# node_00209.png: [OCR failed]
# node_00210.png: [OCR failed]
# node_00211.png: '1'
# node_00212.png: '4'
# node_00213.png: [OCR failed]
# node_00214.png: '3'
# node_00215.png: '2'
# node_00216.png: [OCR failed]
# node_00217.png: [OCR failed]
# node_00218.png: '2'
# node_00219.png: '4'
# node_00220.png: '3'
# node_00221.png: '1'
# node_00222.png: '2'
# node_00223.png: '3'
# node_00224.png: [OCR failed]
# node_00225.png: '0'
# node_00226.png: '4'
# node_00227.png: '3'
# node_00228.png: '0'
# node_00229.png: [OCR failed]
# node_00230.png: '4'
# node_00231.png: [OCR failed]
# node_00232.png: '5'
# node_00233.png: '2'
# node_00234.png: '4'
# node_00235.png: [OCR failed]
# node_00236.png: '0'
# node_00237.png: '3'
# node_00238.png: '2'
# node_00239.png: '4'
# node_00240.png: '0'
# node_00241.png: '3'
# node_00242.png: [OCR failed]
# node_00243.png: '2'
# node_00244.png: '4'
# node_00245.png: [OCR failed]
# node_00246.png: '3'
# node_00247.png: '0'
# node_00248.png: '2'
# node_00249.png: '1'
# node_00250.png: '3'
# node_00251.png: [OCR failed]
# node_00252.png: '4'
# node_00253.png: '0'
# node_00254.png: '4'
# node_00255.png: '2'
# node_00256.png: '1'
# node_00257.png: '3'
# node_00258.png: [OCR failed]
# node_00259.png: [OCR failed]
# node_00260.png: '3'
# node_00261.png: '5'
# node_00262.png: [OCR failed]
# node_00263.png: '4'
# node_00264.png: [OCR failed]
# node_00265.png: [OCR failed]
# node_00266.png: '1'
# node_00267.png: [OCR failed]
# node_00268.png: [OCR failed]
# node_00269.png: '1'
# node_00270.png: [OCR failed]
# node_00271.png: [OCR failed]
# node_00272.png: '1'
# node_00273.png: '2'
# node_00274.png: '0'
# node_00275.png: '1'
# node_00276.png: '3'
# node_00277.png: '1'
# node_00278.png: '0'
# node_00279.png: '5'
# node_00280.png: '4'
# node_00281.png: [OCR failed]
# node_00282.png: '2'
# node_00283.png: '3'
# node_00284.png: '1'
# node_00285.png: '0'
# node_00286.png: '2'
# node_00287.png: '3'
# node_00288.png: '2'
# node_00289.png: '1'
# node_00290.png: '9'
# node_00291.png: [OCR failed]
# node_00292.png: [OCR failed]
# node_00293.png: '1'
# node_00294.png: '0'
# node_00295.png: '4'
# node_00296.png: '0'
# node_00297.png: '5'
# node_00298.png: '1'
# node_00299.png: '3'
# node_00300.png: '2'
# node_00301.png: '0'
# node_00302.png: '2'
# node_00303.png: [OCR failed]
# node_00304.png: '4'
# node_00305.png: '1'
# node_00306.png: '5'
# node_00307.png: '5'
# node_00308.png: [OCR failed]
# node_00309.png: '4'
# node_00310.png: '0'
# node_00311.png: '1'
# node_00312.png: '2'
# node_00313.png: [OCR failed]
# node_00314.png: '3'
# node_00315.png: '2'
# node_00316.png: '1'
# node_00317.png: '5'
# node_00318.png: '4'
# node_00319.png: '0'
# node_00320.png: [OCR failed]
# node_00321.png: '2'
# node_00322.png: [OCR failed]
# node_00323.png: [OCR failed]
# node_00324.png: [OCR failed]
# node_00325.png: '4'
# node_00326.png: [OCR failed]
# node_00327.png: '2'
# node_00328.png: [OCR failed]
# node_00329.png: '5'
# node_00330.png: '2'
# node_00331.png: '4'
# node_00332.png: '3'
# node_00333.png: '0'
# node_00334.png: '0'
# node_00335.png: '2'
# node_00336.png: '1'
# node_00337.png: '3'
# node_00338.png: '4'
# node_00339.png: '3'
# node_00340.png: '1'
# node_00341.png: '0'
# node_00342.png: '2'
# node_00343.png: '5'
# node_00344.png: [OCR failed]
# node_00345.png: '2'
# node_00346.png: '5'
# node_00347.png: [OCR failed]
# node_00348.png: '4'
# node_00349.png: '1'
# node_00350.png: '5'
# node_00351.png: '4'
# node_00352.png: '1'
# node_00353.png: '2'
# node_00354.png: '0'
# node_00355.png: [OCR failed]
# node_00356.png: '2'
# node_00357.png: [OCR failed]
# node_00358.png: '0'
# node_00359.png: '3'
# node_00360.png: '3'
# node_00361.png: [OCR failed]
# node_00362.png: '0'
# node_00363.png: '4'
# node_00364.png: '2'
# node_00365.png: '5'
# node_00366.png: '1'
# node_00367.png: '3'
# node_00368.png: '2'
# node_00369.png: [OCR failed]
# node_00370.png: [OCR failed]
# node_00371.png: [OCR failed]
# node_00372.png: '1'
# node_00373.png: [OCR failed]
# node_00374.png: [OCR failed]
# node_00375.png: '1'
# node_00376.png: '2'
# node_00377.png: '0'
# node_00378.png: '3'
# node_00379.png: '1'
# node_00380.png: '4'
# node_00381.png: '2'
# node_00382.png: '1'
# node_00383.png: '0'
# node_00384.png: '3'
# node_00385.png: [OCR failed]
# node_00386.png: [OCR failed]
# node_00387.png: '1'
# node_00388.png: [OCR failed]
# node_00389.png: [OCR failed]
# node_00390.png: '1'
# node_00391.png: '1'
# node_00392.png: '0'
# node_00393.png: '2'
# node_00394.png: '3'
# node_00395.png: '0'
# node_00396.png: '1'
# node_00397.png: '4'
# node_00398.png: '3'
# node_00399.png: '2'
# node_00400.png: '0'
# node_00401.png: '1'
# node_00402.png: '3'
# node_00403.png: '2'
# node_00404.png: '3'
# node_00405.png: '1'
# node_00406.png: '0'
# node_00407.png: '2'
# node_00408.png: '2'
# node_00409.png: [OCR failed]
# node_00410.png: '1'
# node_00411.png: [OCR failed]
# node_00412.png: '4'
# node_00413.png: [OCR failed]
# node_00414.png: [OCR failed]
# node_00415.png: '1'
# node_00416.png: [OCR failed]
# node_00417.png: [OCR failed]
# node_00418.png: '1'
# node_00419.png: [OCR failed]
# node_00420.png: [OCR failed]
# node_00421.png: '4'
# node_00422.png: [OCR failed]
# node_00423.png: [OCR failed]
# node_00424.png: [OCR failed]
# node_00425.png: [OCR failed]
# node_00426.png: '1'
# node_00427.png: '1'
# node_00428.png: '2'
# node_00429.png: '3'
# node_00430.png: '0'
# node_00431.png: '5'
# node_00432.png: '4'
# node_00433.png: [OCR failed]
# node_00434.png: [OCR failed]
# node_00435.png: '4'
# node_00436.png: [OCR failed]
# node_00437.png: [OCR failed]
# node_00438.png: [OCR failed]
# node_00439.png: '1'
# node_00440.png: '3'
# node_00441.png: '2'
# node_00442.png: '4'
# node_00443.png: '3'
# node_00444.png: '1'
# node_00445.png: '2'
# node_00446.png: [OCR failed]
# node_00447.png: '2'
# node_00448.png: '1'
# node_00449.png: '0'
# node_00450.png: '3'
# node_00451.png: '0'
# node_00452.png: '1'
# node_00453.png: '4'
# node_00454.png: [OCR failed]
# node_00455.png: '2'
# node_00456.png: [OCR failed]
# node_00457.png: '0'
# node_00458.png: '2'
# node_00459.png: [OCR failed]
# node_00460.png: '4'
# node_00461.png: '0'
# node_00462.png: '3'
# node_00463.png: [OCR failed]
# node_00464.png: '2'
# node_00465.png: '3'
# node_00466.png: [OCR failed]
# node_00467.png: '2'
# node_00468.png: '1'
# node_00469.png: '2'
# node_00470.png: '1'
# node_00471.png: '0'
# node_00472.png: '3'
# node_00473.png: '1'
# node_00474.png: '3'
# node_00475.png: '0'
# node_00476.png: '4'
# node_00477.png: '2'
# node_00478.png: [OCR failed]
# node_00479.png: [OCR failed]
# node_00480.png: '1'
# node_00481.png: '4'
# node_00482.png: '5'
# node_00483.png: '1'
# node_00484.png: [OCR failed]
# node_00485.png: '0'
# node_00486.png: '3'
# node_00487.png: [OCR failed]
# node_00488.png: '4'
# node_00489.png: '3'
# node_00490.png: '2'
# node_00491.png: [OCR failed]
# node_00492.png: '5'
# node_00493.png: [OCR failed]
# node_00494.png: [OCR failed]
# node_00495.png: '1'
# node_00496.png: '0'
# node_00497.png: '2'
# node_00498.png: '1'
# node_00499.png: '4'
# node_00500.png: '3'
# node_00501.png: [OCR failed]
# node_00502.png: [OCR failed]
# node_00503.png: '1'
# node_00504.png: '2'
# node_00505.png: '3'
# node_00506.png: '0'
# node_00507.png: '1'
# node_00508.png: '3'
# node_00509.png: '1'
# node_00510.png: [OCR failed]
# node_00511.png: '0'
# node_00512.png: [OCR failed]
# node_00513.png: [OCR failed]
# node_00514.png: '1'
# node_00515.png: '0'
# node_00516.png: [OCR failed]
# node_00517.png: '1'
# node_00518.png: '2'
# node_00519.png: [OCR failed]
# node_00520.png: '4'
# node_00521.png: '3'
# node_00522.png: '2'
# node_00523.png: '0'
# node_00524.png: [OCR failed]
# node_00525.png: '4'
# node_00526.png: '5'
# node_00527.png: '3'
# node_00528.png: [OCR failed]
# node_00529.png: '1'
# node_00530.png: '2'
# node_00531.png: '4'
# node_00532.png: '1'
# node_00533.png: '0'
# node_00534.png: '3'
# node_00535.png: '0'
# node_00536.png: [OCR failed]
# node_00537.png: '2'
# node_00538.png: '4'
# node_00539.png: '3'
# node_00540.png: [OCR failed]
# node_00541.png: [OCR failed]
# node_00542.png: '1'
# node_00543.png: [OCR failed]
# node_00544.png: [OCR failed]
# node_00545.png: '1'
# node_00546.png: [OCR failed]
# node_00547.png: '3'
# node_00548.png: [OCR failed]
# node_00549.png: '4'
# node_00550.png: '0'
# node_00551.png: '5'
# node_00552.png: '4'
# node_00553.png: '0'
# node_00554.png: '2'
# node_00555.png: '1'
# node_00556.png: '3'
# node_00557.png: [OCR failed]
# node_00558.png: [OCR failed]
# node_00559.png: '1'
# node_00560.png: [OCR failed]
# node_00561.png: '4'
# node_00562.png: '3'
# node_00563.png: '0'
# node_00564.png: '5'
# node_00565.png: '1'
# node_00566.png: [OCR failed]
# node_00567.png: [OCR failed]
# node_00568.png: '1'
# node_00569.png: '0'
# node_00570.png: '3'
# node_00571.png: '1'
# node_00572.png: '2'
# node_00573.png: [OCR failed]
# node_00574.png: [OCR failed]
# node_00575.png: '1'
# node_00576.png: '3'
# node_00577.png: [OCR failed]
# node_00578.png: '0'
# node_00579.png: '2'
# node_00580.png: '4'
# node_00581.png: [OCR failed]
# node_00582.png: '3'
# node_00583.png: '1'
# node_00584.png: '2'
# node_00585.png: [OCR failed]
# node_00586.png: [OCR failed]
# node_00587.png: '4'
# node_00588.png: [OCR failed]
# node_00589.png: [OCR failed]
# node_00590.png: '0'
# node_00591.png: '3'
# node_00592.png: '1'
# node_00593.png: '2'
# node_00594.png: [OCR failed]
# node_00595.png: [OCR failed]
# node_00596.png: '1'
# node_00597.png: '3'
# node_00598.png: '0'
# node_00599.png: '2'
# node_00600.png: '1'
# node_00601.png: '4'
# node_00602.png: '5'
# node_00603.png: '2'
# node_00604.png: [OCR failed]
# node_00605.png: [OCR failed]
# node_00606.png: '0'
# node_00607.png: [OCR failed]
# node_00608.png: '0'
# node_00609.png: [OCR failed]
# node_00610.png: '2'
# node_00611.png: '0'
# node_00612.png: '4'
# node_00613.png: '5'
# node_00614.png: '3'
# node_00615.png: '1'
# node_00616.png: '2'
# node_00617.png: [OCR failed]
# node_00618.png: '2'
# node_00619.png: '4'
# node_00620.png: [OCR failed]
# node_00621.png: '0'
# node_00622.png: '0'
# node_00623.png: '3'
# node_00624.png: '1'
# node_00625.png: '4'
# node_00626.png: [OCR failed]
# node_00627.png: '0'
# node_00628.png: [OCR failed]
# node_00629.png: '4'
# node_00630.png: [OCR failed]
# node_00631.png: '5'
# node_00632.png: [OCR failed]
# node_00633.png: [OCR failed]
# node_00634.png: '0'
# node_00635.png: '5'
# node_00636.png: '1'
# node_00637.png: '4'
# node_00638.png: '2'
# node_00639.png: '0'
# node_00640.png: '3'
# node_00641.png: '4'
# node_00642.png: '2'
# node_00643.png: '1'
# node_00644.png: [OCR failed]
# node_00645.png: [OCR failed]
# node_00646.png: '1'
# node_00647.png: '0'
# node_00648.png: '3'
# node_00649.png: '1'
# node_00650.png: [OCR failed]
# node_00651.png: '0'
# node_00652.png: '4'
# node_00653.png: '2'
# node_00654.png: '3'
# node_00655.png: [OCR failed]
# node_00656.png: '1'
# node_00657.png: '2'
# node_00658.png: '1'
# node_00659.png: '3'
# node_00660.png: '4'
# node_00661.png: [OCR failed]
# node_00662.png: [OCR failed]
# node_00663.png: [OCR failed]
# node_00664.png: '1'
# node_00665.png: [OCR failed]
# node_00666.png: [OCR failed]
# node_00667.png: '0'
# node_00668.png: '3'
# node_00669.png: [OCR failed]
# node_00670.png: [OCR failed]
# node_00671.png: '1'
# node_00672.png: [OCR failed]
# node_00673.png: '4'
# node_00674.png: [OCR failed]
# node_00675.png: [OCR failed]
# node_00676.png: '2'
# node_00677.png: '5'
# node_00678.png: '2'
# node_00679.png: '4'
# node_00680.png: '3'
# node_00681.png: '0'
# node_00682.png: '1'
# node_00683.png: [OCR failed]
# node_00684.png: [OCR failed]
# node_00685.png: '1'
# node_00686.png: '1'
# node_00687.png: [OCR failed]
# node_00688.png: '0'
# node_00689.png: '2'
# node_00690.png: '2'
# node_00691.png: '3'
# node_00692.png: '0'
# node_00693.png: '4'
# node_00694.png: '1'
# node_00695.png: '3'
# node_00696.png: '1'
# node_00697.png: '0'
# node_00698.png: '2'
# node_00699.png: [OCR failed]
# node_00700.png: '3'
# node_00701.png: '2'
# node_00702.png: '1'
# node_00703.png: '2'
# node_00704.png: [OCR failed]
# node_00705.png: '4'
# node_00706.png: [OCR failed]
# node_00707.png: [OCR failed]
# node_00708.png: '0'
# node_00709.png: [OCR failed]
# node_00710.png: '2'
# node_00711.png: [OCR failed]
# node_00712.png: [OCR failed]
# node_00713.png: [OCR failed]
# node_00714.png: '1'
# node_00715.png: [OCR failed]
# node_00716.png: '4'
# node_00717.png: '0'
# node_00718.png: '3'
# node_00719.png: '2'
# node_00720.png: [OCR failed]
# node_00721.png: [OCR failed]
# node_00722.png: '1'
# node_00723.png: '5'
# node_00724.png: '2'
# node_00725.png: '3'
# node_00726.png: '1'
# node_00727.png: '0'
# node_00728.png: '4'
# node_00729.png: '1'
# node_00730.png: '5'
# node_00731.png: '4'
# node_00732.png: '0'
# node_00733.png: '3'
# node_00734.png: '2'
# node_00735.png: [OCR failed]
# node_00736.png: '0'
# node_00737.png: '4'
# node_00738.png: '2'
# node_00739.png: [OCR failed]
# node_00740.png: '1'
# node_00741.png: '3'
# node_00742.png: '07'
# node_00743.png: '2'
# node_00744.png: '4'
# node_00745.png: [OCR failed]
# node_00746.png: [OCR failed]
# node_00747.png: '1'
# node_00748.png: [OCR failed]
# node_00749.png: '3'
# node_00750.png: '1'
# node_00751.png: '4'
# node_00752.png: '2'
# node_00753.png: '1'
# node_00754.png: [OCR failed]
# node_00755.png: '3'
# node_00756.png: '0'
# node_00757.png: '0'
# node_00758.png: '1'
# node_00759.png: '4'
# node_00760.png: '3'
# node_00761.png: [OCR failed]
# node_00762.png: [OCR failed]
# node_00763.png: '0'
# node_00764.png: '4'
# node_00765.png: '1'
# node_00766.png: '2'
# node_00767.png: [OCR failed]
# node_00768.png: [OCR failed]
# node_00769.png: '1'
# node_00770.png: '0'
# node_00771.png: '3'
# node_00772.png: '1'
# node_00773.png: '5'
# node_00774.png: '4'
# node_00775.png: '2'
# node_00776.png: '5'
# node_00777.png: '4'
# node_00778.png: '1'
# node_00779.png: '3'
# node_00780.png: '0'
# node_00781.png: '2'
# node_00782.png: '2'
# node_00783.png: '3'
# node_00784.png: '0'
# node_00785.png: '1'
# node_00786.png: [OCR failed]
# node_00787.png: '5'
# node_00788.png: '4'
# node_00789.png: [OCR failed]
# node_00790.png: '2'
# node_00791.png: '0'
# node_00792.png: '3'
# node_00793.png: '0'
# node_00794.png: '1'
# node_00795.png: '2'
# node_00796.png: '1'
# node_00797.png: '2'
# node_00798.png: '0'
# node_00799.png: [OCR failed]
# node_00800.png: '3'
# node_00801.png: '2'
# node_00802.png: '0'
# node_00803.png: '5'
# node_00804.png: '40'
# node_00805.png: '1'
# node_00806.png: '3'
# node_00807.png: '4'
# node_00808.png: '2'
# node_00809.png: '0'
# node_00810.png: '1'
# node_00811.png: [OCR failed]
# node_00812.png: '4'
# node_00813.png: '1'
# node_00814.png: [OCR failed]
# node_00815.png: '2'
# node_00816.png: '3'
# node_00817.png: '2'
# node_00818.png: [OCR failed]
# node_00819.png: [OCR failed]
# node_00820.png: [OCR failed]
# node_00821.png: [OCR failed]
# node_00822.png: '1'
# node_00823.png: '2'
# node_00824.png: '5'
# node_00825.png: '0'
# node_00826.png: '1'
# node_00827.png: '4'
# node_00828.png: '3'
# node_00829.png: '2'
# node_00830.png: '1'
# node_00831.png: '3'
# node_00832.png: '0'
# node_00833.png: '4'
# node_00834.png: '1'
# node_00835.png: [OCR failed]
# node_00836.png: '0'
# node_00837.png: '2'
# node_00838.png: [OCR failed]
# node_00839.png: '1'
# node_00840.png: '3'
# node_00841.png: '2'
# node_00842.png: '0'
# node_00843.png: '4'
# node_00844.png: '2'
# node_00845.png: '3'
# node_00846.png: '1'
# node_00847.png: '5'
# node_00848.png: '1'
# node_00849.png: '3'
# node_00850.png: '2'
# node_00851.png: [OCR failed]
# node_00852.png: [OCR failed]
# node_00853.png: [OCR failed]
# node_00854.png: '1'
# node_00855.png: '3'
# node_00856.png: '2'
# node_00857.png: '0'
# node_00858.png: '1'
# node_00859.png: '3'
# node_00860.png: [OCR failed]
# node_00861.png: '0'
# node_00862.png: '4'
# node_00863.png: '5'
# node_00864.png: '2'
# node_00865.png: '2'
# node_00866.png: '3'
# node_00867.png: '0'
# node_00868.png: '1'
# node_00869.png: '0'
# node_00870.png: [OCR failed]
# node_00871.png: '1'
# node_00872.png: '5'
# node_00873.png: '3'
# node_00874.png: '4'
# node_00875.png: [OCR failed]
# node_00876.png: [OCR failed]
# node_00877.png: '1'
# node_00878.png: '1'
# node_00879.png: '2'
# node_00880.png: '3'
# node_00881.png: '0'
# node_00882.png: '3'
# node_00883.png: '1'
# node_00884.png: '2'
# node_00885.png: '0'
# node_00886.png: '3'
# node_00887.png: '2'
# node_00888.png: [OCR failed]
# node_00889.png: '1'
# node_00890.png: '0'
# node_00891.png: '2'
# node_00892.png: '1'
# node_00893.png: '4'
# node_00894.png: [OCR failed]
# node_00895.png: [OCR failed]
# node_00896.png: [OCR failed]
# node_00897.png: '1'
# node_00898.png: '1'
# node_00899.png: '4'
# node_00900.png: [OCR failed]
# node_00901.png: '0'
# node_00902.png: '2'
# node_00903.png: [OCR failed]
# node_00904.png: '2'
# node_00905.png: '4'
# node_00906.png: '5'
# node_00907.png: '0'
# node_00908.png: '1'
# node_00909.png: [OCR failed]
# node_00910.png: [OCR failed]
# node_00911.png: '1'
# node_00912.png: '4'
# node_00913.png: '3'
# node_00914.png: '0'
# node_00915.png: '1'
# node_00916.png: '2'
# node_00917.png: [OCR failed]
# node_00918.png: [OCR failed]
# node_00919.png: '1'
# node_00920.png: '5'
# node_00921.png: '0'
# node_00922.png: '2'
# node_00923.png: [OCR failed]
# node_00924.png: '1'
# node_00925.png: '4'
# node_00926.png: '3'
# node_00927.png: [OCR failed]
# node_00928.png: '0'
# node_00929.png: [OCR failed]
# node_00930.png: '4'
# node_00931.png: '4'
# node_00932.png: '1'
# node_00933.png: '5'
# node_00934.png: '2'
# node_00935.png: '0'
# node_00936.png: '3'
# node_00937.png: '4'
# node_00938.png: '2'
# node_00939.png: '5'
# node_00940.png: [OCR failed]
# node_00941.png: '3'
# node_00942.png: '0'
# node_00943.png: '2'
# node_00944.png: '7'
# node_00945.png: '4'
# node_00946.png: [OCR failed]
# node_00947.png: '3'
# node_00948.png: [OCR failed]
# node_00949.png: [OCR failed]
# node_00950.png: '1'
# node_00951.png: '4'
# node_00952.png: '0'
# node_00953.png: '1'
# node_00954.png: '2'
# node_00955.png: '3'
# node_00956.png: [OCR failed]
# node_00957.png: [OCR failed]
# node_00958.png: '1'
# node_00959.png: [OCR failed]
# node_00960.png: [OCR failed]
# node_00961.png: '1'
# node_00962.png: [OCR failed]
# node_00963.png: [OCR failed]
# node_00964.png: '1'
# node_00965.png: [OCR failed]
# node_00966.png: [OCR failed]
# node_00967.png: '1'
# node_00968.png: '2'
# node_00969.png: [OCR failed]
# node_00970.png: '3'
# node_00971.png: '4'
# node_00972.png: '5'
# node_00973.png: '1'
# node_00974.png: [OCR failed]
# node_00975.png: [OCR failed]
# node_00976.png: [OCR failed]
# node_00977.png: '4'
# node_00978.png: '3'
# node_00979.png: '0'
# node_00980.png: '5'
# node_00981.png: '0'
# node_00982.png: [OCR failed]
# node_00983.png: '4'
# node_00984.png: '2'
# node_00985.png: '3'
# node_00986.png: '3'
# node_00987.png: '2'
# node_00988.png: '1'
# node_00989.png: '0'
# node_00990.png: '1'
# node_00991.png: '2'
# node_00992.png: '3'
# node_00993.png: '0'
# node_00994.png: '0'
# node_00995.png: '2'
# node_00996.png: '1'
# node_00997.png: [OCR failed]
# node_00998.png: '0'
# node_00999.png: '2'
# node_01000.png: '4'
# node_01001.png: '5'
# node_01002.png: '1'
# node_01003.png: '3'
# node_01004.png: [OCR failed]
# node_01005.png: [OCR failed]
# node_01006.png: '1'
# node_01007.png: '3'
# node_01008.png: '2'
# node_01009.png: '1'
# node_01010.png: '4'
# node_01011.png: [OCR failed]
# node_01012.png: [OCR failed]
# node_01013.png: [OCR failed]
# node_01014.png: '1'
# node_01015.png: [OCR failed]
# node_01016.png: '3'
# node_01017.png: '4'
# node_01018.png: '2'
# node_01019.png: '1'
# node_01020.png: [OCR failed]
# node_01021.png: [OCR failed]
# node_01022.png: '1'
# node_01023.png: '1'
# node_01024.png: '3'
# node_01025.png: '0'
# node_01026.png: '4'
# node_01027.png: [OCR failed]
# node_01028.png: [OCR failed]
# node_01029.png: [OCR failed]
# node_01030.png: '1'
# node_01031.png: [OCR failed]
# node_01032.png: '1'
# node_01033.png: '2'
# node_01034.png: '4'
# node_01035.png: '0'
# node_01036.png: '1'
# node_01037.png: '2'
# node_01038.png: '3'
# node_01039.png: '4'
# node_01040.png: [OCR failed]
# node_01041.png: '5'
# node_01042.png: '4'
# node_01043.png: [OCR failed]
# node_01284.png: [OCR failed]
# node_01285.png: [OCR failed]
# node_01286.png: '0'
# node_01287.png: '0'
# node_01288.png: '3'
# node_01289.png: '2'
# node_01290.png: '1'
# node_01291.png: '7'
# node_01292.png: '5'
# node_01293.png: '1'
# node_01294.png: '2'
# node_01295.png: '4'
# node_01296.png: '3'
# node_01297.png: '1'
# node_01298.png: [OCR failed]
# node_01299.png: '2'
# node_01300.png: '3'
# node_01301.png: [OCR failed]
# node_01302.png: [OCR failed]
# node_01303.png: '1'
# node_01304.png: '4'
# node_01305.png: [OCR failed]
# node_01306.png: [OCR failed]
# node_01307.png: [OCR failed]
# node_01308.png: [OCR failed]
# node_01309.png: '1'
# node_01310.png: '4'
# node_01311.png: '3'
# node_01312.png: '2'
# node_01313.png: [OCR failed]
# node_01314.png: [OCR failed]
# node_01315.png: '2'
# node_01316.png: '5'
# node_01317.png: '1'
# node_01318.png: '4'
# node_01319.png: [OCR failed]
# node_01320.png: '3'
# node_01321.png: [OCR failed]
# node_01322.png: '2'
# node_01323.png: [OCR failed]
# node_01324.png: '4'
# node_01325.png: '1'
# node_01326.png: '2'
# node_01327.png: '0'
# node_01328.png: '4'
# node_01329.png: '1'
# node_01330.png: '3'
# node_01331.png: '2'
# node_01332.png: '1'
# node_01333.png: '5'
# node_01334.png: '3'
# node_01335.png: '4'
# node_01336.png: '0'
# node_01337.png: '0'
# node_01338.png: '2'
# node_01339.png: '1'
# node_01340.png: '3'
# node_01341.png: '3'
# node_01342.png: '1'
# node_01343.png: '2'
# node_01344.png: [OCR failed]
# node_01345.png: [OCR failed]
# node_01346.png: [OCR failed]
# node_01347.png: '1'
# node_01348.png: [OCR failed]
# node_01349.png: '1'
# node_01350.png: '0'
# node_01351.png: '4'
# node_01352.png: '5'
# node_01353.png: '2'
# node_01354.png: '0'
# node_01355.png: '1'
# node_01356.png: '4'
# node_01357.png: '3'
# node_01358.png: '2'
# node_01359.png: [OCR failed]
# node_01360.png: [OCR failed]
# node_01361.png: '1'
# node_01362.png: '0'
# node_01363.png: '3'
# node_01364.png: '1'
# node_01365.png: '2'
# node_01366.png: '4'
# node_01367.png: [OCR failed]
# node_01368.png: '3'
# node_01369.png: '2'
# node_01370.png: '0'
# node_01371.png: '3'
# node_01372.png: [OCR failed]
# node_01373.png: '2'
# node_01374.png: '0'
# node_01375.png: [OCR failed]
# node_01376.png: [OCR failed]
# node_01377.png: '1'
# node_01378.png: '5'
# node_01379.png: '2'
# node_01380.png: '1'
# node_01381.png: '4'
# node_01382.png: [OCR failed]
# node_01383.png: '0'
# node_01384.png: [OCR failed]
# node_01385.png: '2'
# node_01386.png: [OCR failed]
# node_01387.png: [OCR failed]
# node_01388.png: [OCR failed]
# node_01389.png: [OCR failed]
# node_01390.png: '1'
# node_01391.png: '5'
# node_01392.png: '4'
# node_01393.png: '2'
# node_01394.png: '1'
# node_01395.png: '3'
# node_01396.png: [OCR failed]
# node_01397.png: [OCR failed]
# node_01398.png: [OCR failed]
# node_01399.png: '4'
# node_01400.png: '0'
# node_01401.png: '2'
# node_01645.png: [OCR failed]
# node_01646.png: [OCR failed]
# node_01647.png: '1'
# node_01648.png: '2'
# node_01649.png: [OCR failed]
# node_01650.png: '0'
# node_01651.png: '4'
# node_01652.png: [OCR failed]
# node_01653.png: '3'
# node_01654.png: '0'
# node_01655.png: '2'
# node_01656.png: '1'
# node_01657.png: '2'
# node_01658.png: '0'
# node_01659.png: '3'
# node_01660.png: '1'
# node_01661.png: [OCR failed]
# node_01662.png: '4'
# node_01663.png: '2'
# node_01664.png: '3'
# node_01665.png: '5'
# node_01666.png: [OCR failed]
# node_01667.png: [OCR failed]
# node_01668.png: '0'
# node_01669.png: [OCR failed]
# node_01670.png: '4'
# node_01671.png: [OCR failed]
# node_01672.png: '1'
# node_01673.png: '0'
# node_01674.png: [OCR failed]
# node_01675.png: '2'
# node_01676.png: '3'
# node_01677.png: '4'
# node_01678.png: [OCR failed]
# node_01679.png: '1'
# node_01680.png: '5'
# node_01681.png: '0'
# node_01682.png: [OCR failed]
# node_01683.png: [OCR failed]
# node_01684.png: '1'
# node_01685.png: [OCR failed]
# node_01686.png: [OCR failed]
# node_01687.png: '1'
# node_01688.png: [OCR failed]
# node_01689.png: '0'
# node_01690.png: [OCR failed]
# node_01691.png: '4'
# node_01692.png: '2'
# node_01693.png: '3'
# node_01694.png: '4'
# node_01695.png: '0'
# node_01696.png: '5'
# node_01697.png: [OCR failed]
# node_01698.png: [OCR failed]
# node_01699.png: '1'
# node_01700.png: '3'
# node_01701.png: [OCR failed]
# node_01702.png: '4'
# node_01703.png: '2'
# node_01704.png: '5'
# node_01705.png: '3'
# node_01706.png: '5'
# node_01707.png: '4'
# node_01708.png: [OCR failed]
# node_01709.png: '0'
# node_01710.png: '2'
# node_01711.png: [OCR failed]
# node_01712.png: [OCR failed]
# node_01713.png: '1'
# node_01714.png: [OCR failed]
# node_01715.png: [OCR failed]
# node_01716.png: '1'
# node_01717.png: [OCR failed]
# node_01718.png: [OCR failed]
# node_01719.png: '1'
# node_01720.png: [OCR failed]
# node_01721.png: [OCR failed]
# node_01722.png: '1'
# node_01723.png: '1'
# node_01724.png: '0'
# node_01725.png: '4'
# node_01726.png: '3'
# node_01727.png: '2'
# node_01728.png: '3'
# node_01729.png: '1'
# node_01730.png: '0'
# node_01731.png: '2'
# node_01732.png: '3'
# node_01733.png: '1'
# node_01734.png: '4'
# node_01735.png: '2'
# node_01736.png: [OCR failed]
# node_01737.png: [OCR failed]
# node_01738.png: '0'
# node_01739.png: '2'
# node_01740.png: '3'
# node_01741.png: '4'
# node_01742.png: '2'
# node_01743.png: '3'
# node_01744.png: '0'
# node_01745.png: '1'
# node_01746.png: '1'
# node_01747.png: '3'
# node_01748.png: '0'
# node_01749.png: '2'
# node_01750.png: '4'
# node_01751.png: '2'
# node_01752.png: '7'
# node_01753.png: '4'
# node_01754.png: '3'
# node_01755.png: [OCR failed]
# node_01756.png: '0'
# node_01757.png: '3'
# node_01758.png: '1'
# node_01759.png: '2'
# node_01760.png: [OCR failed]
# node_01761.png: [OCR failed]
# node_02003.png: [OCR failed]
# node_02004.png: [OCR failed]
# node_02005.png: '1'
# node_02006.png: '1'
# node_02007.png: '0'
# node_02008.png: '4'
# node_02009.png: [OCR failed]
# node_02010.png: '2'
# node_02011.png: [OCR failed]
# node_02012.png: '3'
# node_02013.png: '4'
# node_02014.png: '2'
# node_02015.png: '1'
# node_02016.png: '4'
# node_02017.png: '3'
# node_02018.png: '2'
# node_02019.png: '0'
# node_02020.png: '5'
# node_02021.png: '1'
# node_02022.png: '2'
# node_02023.png: '1'
# node_02024.png: '4'
# node_02025.png: '5'
# node_02026.png: '3'
# node_02027.png: '0'
# node_02028.png: [OCR failed]
# node_02029.png: [OCR failed]
# node_02030.png: '1'
# node_02031.png: [OCR failed]
# node_02032.png: [OCR failed]
# node_02033.png: '1'
# node_02034.png: '0'
# node_02035.png: [OCR failed]
# node_02036.png: '4'
# node_02037.png: [OCR failed]
# node_02038.png: '1'
# node_02039.png: [OCR failed]
# node_02040.png: [OCR failed]
# node_02041.png: '1'
# node_02042.png: '3'
# node_02043.png: '1'
# node_02044.png: '4'
# node_02045.png: [OCR failed]
# node_02046.png: '2'
# node_02047.png: '5'
# node_02048.png: '2'
# node_02049.png: '4'
# node_02050.png: '1'
# node_02051.png: [OCR failed]
# node_02052.png: '0'
# node_02053.png: '0'
# node_02054.png: '1'
# node_02055.png: '3'
# node_02056.png: '4'
# node_02057.png: '2'
# node_02058.png: '5'
# node_02059.png: '3'
# node_02060.png: '0'
# node_02061.png: '1'
# node_02062.png: '2'
# node_02063.png: [OCR failed]
# node_02064.png: [OCR failed]
# node_02065.png: '1'
# node_02066.png: [OCR failed]
# node_02067.png: [OCR failed]
# node_02068.png: '1'
# node_02069.png: '2'
# node_02070.png: [OCR failed]
# node_02071.png: '0'
# node_02072.png: [OCR failed]
# node_02073.png: '4'
# node_02074.png: '4'
# node_02075.png: '0'
# node_02076.png: [OCR failed]
# node_02077.png: '2'
# node_02078.png: '5'
# node_02079.png: '3'
# node_02080.png: '4'
# node_02081.png: [OCR failed]
# node_02082.png: '0'
# node_02083.png: '2'
# node_02084.png: '5'
# node_02085.png: [OCR failed]
# node_02086.png: '4'
# node_02087.png: [OCR failed]
# node_02088.png: '0'
# node_02089.png: '2'
# node_02090.png: '5'
# node_02091.png: '1'
# node_02092.png: '0'
# node_02093.png: '3'
# node_02094.png: '2'
# node_02095.png: '4'
# node_02096.png: '1'
# node_02097.png: '2'
# node_02098.png: '0'
# node_02099.png: '3'
# node_02100.png: [OCR failed]
# node_02101.png: '3'
# node_02102.png: '1'
# node_02103.png: [OCR failed]
# node_02104.png: '4'
# node_02105.png: '0'
# node_02106.png: '3'
# node_02107.png: '0'
# node_02108.png: '4'
# node_02109.png: '2'
# node_02110.png: '1'
# node_02111.png: '2'
# node_02112.png: '4'
# node_02113.png: '1'
# node_02114.png: [OCR failed]
# node_02115.png: '3'
# node_02116.png: [OCR failed]
# node_02117.png: [OCR failed]
# node_02118.png: '1'
# node_02119.png: [OCR failed]
# node_02120.png: [OCR failed]
# node_02121.png: '1'
# node_02122.png: [OCR failed]
# node_02123.png: [OCR failed]
# node_02124.png: '1'
# node_02125.png: '1'
# node_02126.png: [OCR failed]
# node_02127.png: '2'
# node_02128.png: '0'
# node_02129.png: '1'
# node_02130.png: '0'
# node_02131.png: '3'
# node_02132.png: '2'
# node_02133.png: '5'
# node_02134.png: [OCR failed]
# node_02135.png: '1'
# node_02136.png: '2'
# node_02137.png: '3'
# node_02138.png: '4'
# node_02139.png: [OCR failed]
# node_02140.png: '2'
# node_02141.png: [OCR failed]
# node_02142.png: '4'
# node_02143.png: '0'
# node_02144.png: [OCR failed]
# node_02145.png: [OCR failed]
# node_02146.png: '1'
# node_02147.png: '0'
# node_02148.png: '4'
# node_02149.png: '1'
# node_02150.png: '2'
# node_02151.png: '3'
# node_02152.png: '5'
# node_02153.png: '1'
# node_02154.png: '4'
# node_02155.png: [OCR failed]
# node_02156.png: '3'
# node_02157.png: '2'
# node_02158.png: '2'
# node_02159.png: [OCR failed]
# node_02160.png: '1'
# node_02161.png: '5'
# node_02162.png: [OCR failed]
# node_02163.png: '4'
# node_02164.png: [OCR failed]
# node_02165.png: [OCR failed]
# node_02166.png: '1'
# node_02167.png: '0'
# node_02168.png: '4'
# node_02169.png: [OCR failed]
# node_02170.png: '5'
# node_02171.png: '2'
# node_02172.png: [OCR failed]
# node_02173.png: [OCR failed]
# node_02174.png: [OCR failed]
# node_02175.png: '1'
# node_02176.png: '3'
# node_02177.png: '0'
# node_02178.png: '1'
# node_02179.png: '4'
# node_02180.png: '2'
# node_02181.png: '4'
# node_02182.png: [OCR failed]
# node_02183.png: '2'
# node_02184.png: [OCR failed]
# node_02185.png: '0'
# node_02186.png: '1'
# node_02187.png: '3'
# node_02188.png: '0'
# node_02189.png: '2'
# node_02190.png: '3'
# node_02191.png: '0'
# node_02192.png: '2'
# node_02193.png: '1'
# node_02194.png: '1'
# node_02195.png: '0'
# node_02196.png: '2'
# node_02197.png: '3'
# node_02198.png: '4'
# node_02199.png: [OCR failed]
# node_02200.png: [OCR failed]
# node_02201.png: '1'
# node_02202.png: [OCR failed]
# node_02203.png: [OCR failed]
# node_02204.png: '1'
# node_02205.png: '3'
# node_02206.png: '1'
# node_02207.png: '2'
# node_02208.png: '0'
# node_02209.png: '3'
# node_02210.png: [OCR failed]
# node_02211.png: '1'
# node_02212.png: '0'
# node_02213.png: '0'
# node_02214.png: '1'
# node_02215.png: '2'
# node_02216.png: '4'
# node_02217.png: '3'
# node_02218.png: '2'
# node_02219.png: '3'
# node_02220.png: '0'
# node_02221.png: [OCR failed]
# node_02222.png: '2'
# node_02223.png: '4'
# node_02224.png: '0'
# node_02225.png: [OCR failed]
# node_02226.png: '3'
# node_02227.png: '2'
# node_02228.png: [OCR failed]
# node_02229.png: '0'
# node_02230.png: '1'
# node_02231.png: [OCR failed]
# node_02232.png: '0'
# node_02233.png: '4'
# node_02234.png: [OCR failed]
# node_02235.png: [OCR failed]
# node_02236.png: '5'
# node_02237.png: '4'
# node_02238.png: '3'
# node_02239.png: '2'
# node_02240.png: [OCR failed]
# node_02241.png: '1'
# node_02242.png: '2'
# node_02243.png: '0'
# node_02244.png: '3'
# node_02245.png: '1'
# node_02246.png: '1'
# node_02247.png: '2'
# node_02248.png: '3'
# node_02249.png: '0'
# node_02250.png: [OCR failed]
# node_02251.png: [OCR failed]
# node_02252.png: '1'
# node_02253.png: '0'
# node_02254.png: '4'
# node_02255.png: '1'
# node_02256.png: '3'
# node_02257.png: '2'
# node_02258.png: '0'
# node_02259.png: '3'
# node_02260.png: '2'
# node_02261.png: '1'
# node_02262.png: [OCR failed]
# node_02263.png: '0'
# node_02264.png: [OCR failed]
# node_02265.png: '2'
# node_02266.png: '3'
# node_02267.png: '1'
# node_02268.png: '2'
# node_02269.png: '0'
# node_02270.png: [OCR failed]
# node_02271.png: [OCR failed]
# node_02272.png: '1'
# node_02273.png: [OCR failed]
# node_02274.png: [OCR failed]
# node_02275.png: '1'
# node_02276.png: [OCR failed]
# node_02277.png: '0'
# node_02278.png: '4'
# node_02279.png: '1'
# node_02280.png: '2'
# OCR labeling complete. Saved to nodes_labeled_easyocr.csv

# %% [markdown]
# ### Model to predict the numeral on the node

# %%
# Set random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)
# Configuration
IMAGE_DIR = './images'
CSV_PATH = './nodes_labeled_easyocr.csv'  # Assuming this is the CSV file with labels
IMG_SIZE = 28
NUM_CLASSES = 6 # 0 to 5
BATCH_SIZE = 32
NUM_EPOCHS = 50
LEARNING_RATE = 0.001
N_FOLDS = 5

# Custom Dataset
class DigitDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        label = self.labels[idx]
        # Read image
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        # Resize to required dimensions
        img = cv2.resize(img, (IMG_SIZE, IMG_SIZE))
        # Normalize pixel values to [0,1]
        img = img / 255.0
        # Convert to torch tensor
        img_tensor = torch.tensor(img, dtype=torch.float32).unsqueeze(0)  # Add channel dimension
        return img_tensor, label

# Define our CNN with Min-Pooling (inverse of MaxPooling for white background)
class MinPooling(nn.Module):
    def __init__(self, kernel_size, stride=None, padding=0):
        super(MinPooling, self).__init__()
        self.kernel_size = kernel_size
        self.stride = stride or kernel_size
        self.padding = padding

    def forward(self, x):
        # Invert the image (1 - x) to make min values become max
        inverted = 1 - x
        # Use max pooling on inverted image
        pooled = nn.functional.max_pool2d(inverted, self.kernel_size, self.stride, self.padding)
        # Invert back
        return 1 - pooled

class DigitCNN(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES):
        super(DigitCNN, self).__init__()
        # Convolutional layers
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.min_pool1 = MinPooling(kernel_size=2, stride=2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.relu2 = nn.ReLU()
        self.min_pool2 = MinPooling(kernel_size=2, stride=2)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.relu3 = nn.ReLU()
        self.min_pool3 = MinPooling(kernel_size=2, stride=2)
        # Fully connected layers
        self.fc1 = nn.Linear(128 * 3 * 3, 128)
        self.relu4 = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        # Convolutional layers
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.min_pool1(x)
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.min_pool2(x)
        x = self.conv3(x)
        x = self.relu3(x)
        x = self.min_pool3(x)
        # Flatten
        x = x.view(x.size(0), -1)
        # Fully connected layers
        x = self.fc1(x)
        x = self.relu4(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

def load_data():
    """Load images and labels from CSV."""
    df = pd.read_csv(CSV_PATH)
    # Assuming CSV has columns 'filename' and 'label'
    image_paths = [os.path.join(IMAGE_DIR, filename) for filename in df['filename']]
    labels = df['key'].values
    # Print class distribution
    label_counts = Counter(labels)
    print("Class distribution:", label_counts)
    return image_paths, labels

def compute_class_weights(labels):
    """Compute weights for each class for dealing with class imbalance."""
    labels = labels.astype(int)
    class_counts = np.bincount(labels, minlength=NUM_CLASSES)
    total = len(labels)
    class_weights = total / (NUM_CLASSES * class_counts)
    return torch.FloatTensor(class_weights)

def train_and_validate():
    """Train the model using stratified K-fold cross-validation."""
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    # Load data
    image_paths, labels = load_data()
    # Compute class weights for handling imbalance
    class_weights = compute_class_weights(labels)
    print("Class weights:", class_weights)
    # Setup cross-validation
    skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
    fold_accuracies = []
    best_model = None
    best_accuracy = 0.0
    for fold, (train_idx, val_idx) in enumerate(skf.split(image_paths, labels)):
        print(f"\nTraining fold {fold+1}/{N_FOLDS}")
        # Split data for this fold
        train_paths = [image_paths[i] for i in train_idx]
        train_labels = [labels[i] for i in train_idx]
        val_paths = [image_paths[i] for i in val_idx]
        val_labels = [labels[i] for i in val_idx]
        # Create datasets
        train_dataset = DigitDataset(train_paths, train_labels)
        val_dataset = DigitDataset(val_paths, val_labels)
        # Create data loaders
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
        # Initialize model, loss function, and optimizer
        model = DigitCNN().to(device)
        criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
        optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=3, factor=0.5)
        # Training loop
        for epoch in range(NUM_EPOCHS):
            model.train()
            train_loss = 0.0
            for inputs, targets in train_loader:
                inputs, targets = inputs.to(device), targets.to(device)
                # Zero the parameter gradients
                optimizer.zero_grad()
                # Forward + backward + optimize
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
                train_loss += loss.item() * inputs.size(0)
            train_loss = train_loss / len(train_loader.dataset)
            # Validation
            model.eval()
            val_loss = 0.0
            val_preds = []
            val_targets = []
            with torch.no_grad():
                for inputs, targets in val_loader:
                    inputs, targets = inputs.to(device), targets.to(device)
                    outputs = model(inputs)
                    loss = criterion(outputs, targets)
                    val_loss += loss.item() * inputs.size(0)
                    _, preds = torch.max(outputs, 1)
                    val_preds.extend(preds.cpu().numpy())
                    val_targets.extend(targets.cpu().numpy())
            val_loss = val_loss / len(val_loader.dataset)
            scheduler.step(val_loss)
            val_accuracy = accuracy_score(val_targets, val_preds)
            if (epoch + 1) % 5 == 0:
                print(f"Epoch {epoch+1}/{NUM_EPOCHS}, "
                      f"Train Loss: {train_loss:.4f}, "
                      f"Val Loss: {val_loss:.4f}, "
                      f"Val Accuracy: {val_accuracy:.4f}")
        # Final validation metrics for this fold
        val_accuracy = accuracy_score(val_targets, val_preds)
        print(f"Fold {fold+1} Validation Accuracy: {val_accuracy:.4f}")
        print(classification_report(val_targets, val_preds))
        fold_accuracies.append(val_accuracy)
        # Save best model across folds
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            best_model = model
    print(f"\nCross-Validation Results:")
    print(f"Mean Accuracy: {np.mean(fold_accuracies):.4f}")
    print(f"Std Deviation: {np.std(fold_accuracies):.4f}")
    # Save the best model
    torch.save(best_model.state_dict(), 'best_digit_classifier.pth')
    print(f"Best model saved with accuracy: {best_accuracy:.4f}")
    return best_model

def predict_from_numpy(img_array, model=None):
    """Predict digit from a numpy array."""
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    # Load model if not provided
    if model is None:
        model = DigitCNN()
        model.load_state_dict(torch.load('best_digit_classifier.pth'))
        model.to(device)
    model.eval()
    # Preprocess image array
    img = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    # Convert to grayscale if it's RGB
    if len(img.shape) == 3:
        img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    img = img / 255.0
    img_tensor = torch.tensor(img, dtype=torch.float32).unsqueeze(0).unsqueeze(0).to(device)

    # Get prediction
    with torch.no_grad():
        output = model(img_tensor)
        prob = torch.nn.functional.softmax(output, dim=1)
        confidence, predicted = torch.max(prob, 1)
    return predicted.item(), confidence.item()

if __name__ == "__main__":
    # Train the model
    best_model = train_and_validate()
    # Example of how to use the prediction function with a numpy array
    print("\nExample of prediction from numpy array:")
    # Create a sample 28x28 array (replace with actual image data)
    sample_image = cv2.imread("images/node_00016.png")
    sample_image = sample_image.astype(np.uint8)
    digit, confidence = predict_from_numpy(sample_image)
    print(f"Predicted digit: {digit}, Confidence: {confidence:.4f}")
# Out:
# Using device: cuda
# Class distribution: Counter({np.int64(0): 501, np.int64(2): 500, np.int64(1): 500, np.int64(3): 396, np.int64(4): 264, np.int64(5): 120})
# Class weights: tensor([0.7588, 0.7603, 0.7603, 0.9600, 1.4400, 3.1681])
#
# Training fold 1/5
# Epoch 5/50, Train Loss: 0.0207, Val Loss: 0.0003, Val Accuracy: 1.0000
# Epoch 10/50, Train Loss: 0.0134, Val Loss: 0.0000, Val Accuracy: 1.0000
# Epoch 15/50, Train Loss: 0.0167, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 20/50, Train Loss: 0.0129, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 25/50, Train Loss: 0.0111, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 30/50, Train Loss: 0.0101, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 35/50, Train Loss: 0.0115, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 40/50, Train Loss: 0.0085, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 45/50, Train Loss: 0.0099, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 50/50, Train Loss: 0.0094, Val Loss: 0.0001, Val Accuracy: 1.0000
# Fold 1 Validation Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       101
#            1       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#            3       1.00      1.00      1.00        80
#            4       1.00      1.00      1.00        52
#            5       1.00      1.00      1.00        24
#
#     accuracy                           1.00       457
#    macro avg       1.00      1.00      1.00       457
# weighted avg       1.00      1.00      1.00       457
#
#
# Training fold 2/5
# Epoch 5/50, Train Loss: 0.0296, Val Loss: 0.0003, Val Accuracy: 1.0000
# Epoch 10/50, Train Loss: 0.0202, Val Loss: 0.0019, Val Accuracy: 1.0000
# Epoch 15/50, Train Loss: 0.0191, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 20/50, Train Loss: 0.0169, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 25/50, Train Loss: 0.0166, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 30/50, Train Loss: 0.0116, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 35/50, Train Loss: 0.0101, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 40/50, Train Loss: 0.0165, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 45/50, Train Loss: 0.0106, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 50/50, Train Loss: 0.0136, Val Loss: 0.0001, Val Accuracy: 1.0000
# Fold 2 Validation Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#            3       1.00      1.00      1.00        79
#            4       1.00      1.00      1.00        53
#            5       1.00      1.00      1.00        24
#
#     accuracy                           1.00       456
#    macro avg       1.00      1.00      1.00       456
# weighted avg       1.00      1.00      1.00       456
#
#
# Training fold 3/5
# Epoch 5/50, Train Loss: 0.0392, Val Loss: 0.0155, Val Accuracy: 0.9978
# Epoch 10/50, Train Loss: 0.0157, Val Loss: 0.0225, Val Accuracy: 0.9978
# Epoch 15/50, Train Loss: 0.0075, Val Loss: 0.0253, Val Accuracy: 0.9978
# Epoch 20/50, Train Loss: 0.0108, Val Loss: 0.0252, Val Accuracy: 0.9978
# Epoch 25/50, Train Loss: 0.0084, Val Loss: 0.0257, Val Accuracy: 0.9978
# Epoch 30/50, Train Loss: 0.0083, Val Loss: 0.0267, Val Accuracy: 0.9978
# Epoch 35/50, Train Loss: 0.0082, Val Loss: 0.0270, Val Accuracy: 0.9978
# Epoch 40/50, Train Loss: 0.0104, Val Loss: 0.0271, Val Accuracy: 0.9978
# Epoch 45/50, Train Loss: 0.0078, Val Loss: 0.0270, Val Accuracy: 0.9978
# Epoch 50/50, Train Loss: 0.0096, Val Loss: 0.0270, Val Accuracy: 0.9978
# Fold 3 Validation Accuracy: 0.9978
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            2       1.00      0.99      0.99       100
#            3       0.99      1.00      0.99        79
#            4       1.00      1.00      1.00        53
#            5       1.00      1.00      1.00        24
#
#     accuracy                           1.00       456
#    macro avg       1.00      1.00      1.00       456
# weighted avg       1.00      1.00      1.00       456
#
#
# Training fold 4/5
# Epoch 5/50, Train Loss: 0.0291, Val Loss: 0.0013, Val Accuracy: 1.0000
# Epoch 10/50, Train Loss: 0.0181, Val Loss: 0.0002, Val Accuracy: 1.0000
# Epoch 15/50, Train Loss: 0.0175, Val Loss: 0.0005, Val Accuracy: 1.0000
# Epoch 20/50, Train Loss: 0.0105, Val Loss: 0.0000, Val Accuracy: 1.0000
# Epoch 25/50, Train Loss: 0.0124, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 30/50, Train Loss: 0.0124, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 35/50, Train Loss: 0.0098, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 40/50, Train Loss: 0.0116, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 45/50, Train Loss: 0.0093, Val Loss: 0.0001, Val Accuracy: 1.0000
# Epoch 50/50, Train Loss: 0.0094, Val Loss: 0.0001, Val Accuracy: 1.0000
# Fold 4 Validation Accuracy: 1.0000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       100
#            1       1.00      1.00      1.00       100
#            2       1.00      1.00      1.00       100
#            3       1.00      1.00      1.00        79
#            4       1.00      1.00      1.00        53
#            5       1.00      1.00      1.00        24
#
#     accuracy                           1.00       456
#    macro avg       1.00      1.00      1.00       456
# weighted avg       1.00      1.00      1.00       456
#
#
# Training fold 5/5
# Epoch 5/50, Train Loss: 0.0298, Val Loss: 0.0282, Val Accuracy: 0.9978
# Epoch 10/50, Train Loss: 0.0202, Val Loss: 0.0296, Val Accuracy: 0.9978
# Epoch 15/50, Train Loss: 0.0111, Val Loss: 0.0361, Val Accuracy: 0.9978
# Epoch 20/50, Train Loss: 0.0107, Val Loss: 0.0335, Val Accuracy: 0.9978
# Epoch 25/50, Train Loss: 0.0061, Val Loss: 0.0356, Val Accuracy: 0.9978
# Epoch 30/50, Train Loss: 0.0103, Val Loss: 0.0368, Val Accuracy: 0.9978
# Epoch 35/50, Train Loss: 0.0071, Val Loss: 0.0367, Val Accuracy: 0.9978
# Epoch 40/50, Train Loss: 0.0085, Val Loss: 0.0368, Val Accuracy: 0.9978
# Epoch 45/50, Train Loss: 0.0093, Val Loss: 0.0368, Val Accuracy: 0.9978
# Epoch 50/50, Train Loss: 0.0063, Val Loss: 0.0369, Val Accuracy: 0.9978
# Fold 5 Validation Accuracy: 0.9978
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       100
#            1       1.00      1.00      1.00       100
#            2       0.99      1.00      1.00       100
#            3       1.00      1.00      1.00        79
#            4       1.00      1.00      1.00        53
#            5       1.00      1.00      1.00        24
#
#     accuracy                           1.00       456
#    macro avg       1.00      1.00      1.00       456
# weighted avg       1.00      1.00      1.00       456
#
#
# Cross-Validation Results:
# Mean Accuracy: 0.9991
# Std Deviation: 0.0011
# Best model saved with accuracy: 1.0000
#
# Example of prediction from numpy array:
# Predicted digit: 1, Confidence: 1.0000
